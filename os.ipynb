# %%
import os

# %%
print(os.getcwd())
# Out:
# c:\Users\Himanshu Khandelwal\Downloads\Trahymam\Projects\tr-upscale-img\pytorch

# %%
os.chdir('./train')
print(os.getcwd())
# Out:
# c:\Users\Himanshu Khandelwal\Downloads\Trahymam\Projects\tr-upscale-img\pytorch\train

# %%
os.chdir('../')
print(os.getcwd())
# Out:
# c:\Users\Himanshu Khandelwal\Downloads\Trahymam\Projects\tr-upscale-img\pytorch

# %%
os.mkdir('images')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 os.mkdir('images')
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'images'

# %%
print(os.listdir('./train'))
# Out:
# ['DSC_2647.JPG', 'DSC_2648.JPG', 'DSC_2649.JPG', 'DSC_2650.JPG', 'DSC_2651.JPG', 'DSC_2652.JPG', 'DSC_2653.JPG', 'DSC_2654.JPG', 'DSC_2655.JPG', 'DSC_2658.JPG', 'DSC_2659.JPG', 'DSC_2660.JPG', 'DSC_2661.JPG', 'DSC_2662.JPG', 'DSC_2663.JPG', 'DSC_2666.JPG', 'DSC_2667.JPG', 'DSC_2669.JPG', 'DSC_2670.JPG', 'DSC_2671.JPG', 'DSC_2672.JPG', 'DSC_2673.JPG', 'DSC_2674.JPG', 'DSC_2675.JPG', 'DSC_2677.JPG', 'DSC_2678.JPG', 'DSC_2679.JPG', 'DSC_2680.JPG', 'DSC_2681.JPG', 'DSC_2682.JPG', 'DSC_2683.JPG', 'DSC_2684.JPG', 'DSC_2685.JPG', 'DSC_2686.JPG', 'DSC_2687.JPG', 'DSC_2688.JPG', 'DSC_2691.JPG', 'DSC_2692.JPG', 'DSC_2693.JPG', 'DSC_2694.JPG', 'DSC_2695.JPG', 'DSC_2696.JPG', 'DSC_2697.JPG', 'DSC_2698.JPG', 'DSC_2699.JPG', 'DSC_2702.JPG', 'DSC_2703.JPG', 'DSC_2706.JPG', 'DSC_2707.JPG', 'DSC_2708.JPG', 'DSC_2709.JPG', 'DSC_2710.JPG', 'DSC_2711.JPG', 'DSC_2712.JPG', 'DSC_2714.JPG', 'DSC_2715.JPG', 'DSC_2716.JPG', 'DSC_2717.JPG', 'DSC_2718.JPG', 'DSC_2719.JPG', 'DSC_2720.JPG', 'DSC_2721.JPG', 'DSC_
# ...

# %%
os.remove('IISC.jpg')

# %%
os.remove('images')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 os.remove('images')
#
# PermissionError: [WinError 5] Access is denied: 'images'

# %%
os.rmdir('images')

# %%
os.rmdir('train')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 os.rmdir('train')
#
# OSError: [WinError 145] The directory is not empty: 'train'

# %%
os.stat('train')
# Out:
# os.stat_result(st_mode=16895, st_ino=10133099162162281, st_dev=3466125589, st_nlink=1, st_uid=0, st_gid=0, st_size=696320, st_atime=1769009040, st_mtime=1768991156, st_ctime=1768891122)

# %%
print(os.name)
# Out:
# nt
